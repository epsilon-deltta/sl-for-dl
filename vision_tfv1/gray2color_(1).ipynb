# %% [markdown]
# ## gray to color (CycleGAN)

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

# %%
# tensorflow 1.x 버전 호환 관련 설정
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth=True
session = InteractiveSession(config=config)

# %%
# !pip install utils
# Out:
# Collecting utils
#   Downloading utils-1.0.1-py2.py3-none-any.whl (21 kB)
# Installing collected packages: utils
# Successfully installed utils-1.0.1

# %%
from tensorflow.keras.layers import Activation, Dense, Input, concatenate
from tensorflow.keras.layers import Conv2D, Flatten, Conv2DTranspose, LeakyReLU, BatchNormalization
from tensorflow.keras.optimizers import RMSprop, Adam
from tensorflow.keras.layers import Reshape, Dropout, ZeroPadding2D, Add, add
from tensorflow.keras.models import Model
from tensorflow.keras import backend as k
from tensorflow.keras.utils import plot_model
import scipy
import matplotlib.pyplot as plt
import numpy as np
import os
import other_utils
import instancenormalization

# %%
def build_generator_unet(input_shape, output_shape, kernel_size, gen_n_filters):
    def encoder(layer_input, filters, strides=2, activation='relu'):
        conv = Conv2D(filters, kernel_size=kernel_size, strides=strides, padding='same')
        d = instancenormalization.InstanceNormalization(axis=-1, center=False, scale=False)(layer_input)
        if activation == 'relu':
            d = Activation('relu')(d)
        else:
            d = LeakyReLU(alpha=0.2)(d)
        d = conv(d)
        return d
    def decoder(layer_input, concate_input, filters, activation='relu'):
        conv = Conv2DTranspose(filters, kernel_size, strides=2, padding='same')
        u = instancenormalization.InstanceNormalization(axis=-1, center=False, scale=False)(layer_input)
        if activation == 'relu':
            u = Activation('relu')(u)
        else:
            u = LeakyReLU(alpha=0.2)(u)
        u = conv(u)
        u = concatenate([u, concate_input])
        return u
    img = Input(shape=input_shape)
    channels = int(output_shape[-1])
    
    d1 = encoder(img, gen_n_filters, strides=1, activation='notrelu')
    d2 = encoder(d1, gen_n_filters*2, activation='notrelu')
    d3 = encoder(d2, gen_n_filters*4, activation='notrelu')
    d4 = encoder(d3, gen_n_filters*8, activation='notrelu')
    u1 = decoder(d4, d3, gen_n_filters*4)
    u2 = decoder(u1, d2, gen_n_filters*2)
    u3 = decoder(u2, d1, gen_n_filters)
    
    output = Conv2DTranspose(channels, kernel_size=kernel_size, strides=1, padding='same', activation='relu')(u3)
    generator = Model(img, output)
    return generator

# %%
def build_generator_resnet(input_shape, kernel_size, gen_n_filters, output_shape=None):
    def conv7s1(layer_input, filters, final):
        y = Conv2D(filters, kernel_size=(7,7), strides=1, padding='same')(layer_input)
        if final:
            y = Activation('tanh')(y)
        else:
            y = instancenormalization.InstanceNormalization(axis=-1, center=False, scale=False)(y)
        return y
    def encoder(layer_input, filters):
        y = Conv2D(filters, kernel_size=Kernel_size, strides=2, padding='same')(layer_input)
        y = instancenormalization.InstanceNormalization(axis=-1, center=False, scale=False)(y)
        y = Activation('relu')(y)
        return y
    def residual(layer_input, filters):
        short_cut = layer_input
        y = Conv2D(filters, kernel_size=kernel_size, strides=1, padding='same')(layer_input)
        y = instancenormalization.InstanceNormalization(axis=-1, center=False, scale=False)(y)
        y = Activation('relu')(y)
        y = Conv2D(filters, kernel_size=kernel_size, strides=1, padding='same')(y)
        y = instancenormalization.InstanceNormalization(axis=-1, center=False, scale=False)(y)
        return add([short_cut, y])
    def decoder(layer_input, filters):
        y = Conv2DTranspose(filters, kernel_size=kernel_size, strides=2, padding='same')(layer_input)
        y = instancenormalization.InstanceNormalization(axis=-1, center=False, scale=False)(y)
        y = Activation('relu')(y)
        return y
    img = Input(shape=input_shape)
    channels = int(output_shape[-1])
    y = conv7s1(img, gen_n_filters, False)
    y = encoder(y, gen_n_filters*2)
    y = encoder(y, gen_n_filters*4)
    y = residual(y, gen_n_filters*4)
    y = residual(y, gen_n_filters*4)
    y = residual(y, gen_n_filters*4)
    y = residual(y, gen_n_filters*4)
    y = residual(y, gen_n_filters*4)
    y = residual(y, gen_n_filters*4)
    y = residual(y, gen_n_filters*4)
    y = residual(y, gen_n_filters*4)
    y = residual(y, gen_n_filters*4)
    y = decoder(y, gen_n_filters*2)
    y = decoder(y, gen_n_filters)
    output = conv7s1(y, channels, True)
    generator = Model(img, output)
    return generator

# %%
def build_discriminator(input_shape, kernel_size, dis_n_filters, patchgan=False):
    def conv(layer_input, filters, strides=2):
        conv = Conv2D(filters, kernel_size=kernel_size, strides=strides, padding='same')
        y = LeakyReLU(0.2)(layer_input)
        y = conv(y)
        return y
    img = Input(shape=input_shape)
    y = conv(img, dis_n_filters)
    y = conv(y, dis_n_filters*2)
    y = conv(y, dis_n_filters*4)
    y = conv(y, dis_n_filters*8)
    if patchgan:
        y = LeakyReLU(alpha=0.2)(y)
        output = Conv2D(1, kernel_size=kernel_size, strides=1, padding='same')(y)
    else:
        y = Flatten()(y)
        y = Dense(1)(y)
        output = Activation('linear')(y)
    discriminator = Model(img, output)
    return discriminator

# %%
def build_cyclegan(shapes, dis_n_filters, gen_n_filters, kernel_size, unet=True, patchgan=False, identity=False):
    A_shape, B_shape = shapes
    d_A = build_discriminator(A_shape, kernel_size, dis_n_filters, patchgan=patchgan)
    d_B = build_discriminator(B_shape, kernel_size, dis_n_filters, patchgan=patchgan)
    d_A.summary()
    d_B.summary()
    d_A.compile(loss='mse', optimizer=RMSprop(lr=2e-4, decay=6e-8))
    d_B.compile(loss='mse', optimizer=RMSprop(lr=2e-4, decay=6e-8))
    if unet:
        g_AB = build_generator_unet(A_shape, B_shape, kernel_size, gen_n_filters)
        g_BA = build_generator_unet(B_shape, A_shape, kernel_size, gen_n_filters)
    else:
        g_AB = build_generator_resnet(A_shape, B_shape, kernel_size, gen_n_filters)
        g_BA = build_generator_resnet(B_shape, A_shape, kernel_size, gen_n_filters)
    d_A.trainable = False
    d_B.trainable = False
    g_AB.summary()
    g_BA.summary()
    img_A = Input(shape=A_shape)
    img_B = Input(shape=B_shape)
    fake_A = g_BA(img_B)
    fake_B = g_AB(img_A)
    valid_A = d_A(fake_A)
    valid_B = d_B(fake_B)
    recons_A = g_BA(fake_B)
    recons_B = g_AB(fake_A)
    
    if identity:
        img_A_id = g_BA(img_A)
        img_B_id = g_AB(img_B)
        inputs = [img_A, img_B]
        outputs = [valid_A, valid_B, recons_A, recons_B, img_A_id, img_B_id]
        loss = ['mse', 'mse', 'mae', 'mae', 'mae', 'mae']
        loss_weights = [1., 1., 10., 10., 0.5, 0.5]
    else:
        inputs = [img_A, img_B]
        outputs = [valid_A, valid_B, recons_A, recons_B]
        loss = ['mse', 'mse', 'mae', 'mae']
        loss_weights = [1., 1., 10., 10.]
    adv = Model(inputs, outputs)
    adv.compile(loss=loss, optimizer=RMSprop(lr=2e-4, decay=6e-8), loss_weights=loss_weights)
    return d_A, d_B, g_AB, g_BA, adv

# %%
import cifar10_utils

# %%
batch_size = 2
train_steps=100000
patchgan=True
identity=False
save_interval=10000
kernel_size=3
gen_n_filters=32
dis_n_filters=32

# %%
data, shapes = cifar10_utils.load_cifar10()
print(shapes)
# Out:
# ((32, 32, 1), (32, 32, 3))

# %%
A_data, B_data, test_A_data, test_B_data = data

# %%
titles = ('CIFAR110 predicted A images', 'CIFAR10 predicted B images', 
          'CIFAR10 reconstructed A images', 'CIFAR10 reconstructed B images')
B_size = int(B_data.shape[0])
A_size = int(A_data.shape[0])

# %%
models = build_cyclegan(shapes, gen_n_filters, dis_n_filters, kernel_size, patchgan=patchgan, identity=identity)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 32, 32, 1)]       0
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 32)        320
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 8, 8, 64)          18496
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 4, 4, 128)         73856
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 2, 2, 256)         295168
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 2, 2, 1)           2305
# =================================================================
# Total params: 390,145
# Trainable params: 390,145
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 16, 16, 32)        896
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 8, 8, 64)          18496
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 4, 4, 128)         73856
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 4, 4, 128)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 2, 2, 256)         295168
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 2, 2, 1)           2305
# =================================================================
# Total params: 390,721
# Trainable params: 390,721
# Non-trainable params: 0
# _________________________________________________________________
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 32, 32, 1)]  0
# __________________________________________________________________________________________________
# instance_normalization (Instanc (None, 32, 32, 1)    0           input_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 32, 32, 1)    0           instance_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 32)   320         leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# instance_normalization_1 (Insta (None, 32, 32, 32)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 32, 32, 32)   0           instance_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 64)   18496       leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# instance_normalization_2 (Insta (None, 16, 16, 64)   0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 16, 16, 64)   0           instance_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 8, 8, 128)    73856       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# instance_normalization_3 (Insta (None, 8, 8, 128)    0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 8, 8, 128)    0           instance_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 4, 4, 256)    295168      leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# instance_normalization_4 (Insta (None, 4, 4, 256)    0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 4, 4, 256)    0           instance_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 128)    295040      activation[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 256)    0           conv2d_transpose[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# instance_normalization_5 (Insta (None, 8, 8, 256)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 8, 8, 256)    0           instance_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 64)   147520      activation_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 128)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# instance_normalization_6 (Insta (None, 16, 16, 128)  0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 16, 16, 128)  0           instance_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 32)   36896       activation_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 64)   0           conv2d_transpose_2[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 3)    1731        concatenate_2[0][0]
# ==================================================================================================
# Total params: 869,027
# Trainable params: 869,027
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_7 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# instance_normalization_7 (Insta (None, 32, 32, 3)    0           input_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 32, 32, 3)    0           instance_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 32)   896         leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# instance_normalization_8 (Insta (None, 32, 32, 32)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 32, 32, 32)   0           instance_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 64)   18496       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# instance_normalization_9 (Insta (None, 16, 16, 64)   0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 16, 16, 64)   0           instance_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 8, 8, 128)    73856       leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# instance_normalization_10 (Inst (None, 8, 8, 128)    0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 8, 8, 128)    0           instance_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 4, 4, 256)    295168      leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# instance_normalization_11 (Inst (None, 4, 4, 256)    0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 4, 4, 256)    0           instance_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 8, 8, 128)    295040      activation_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 8, 256)    0           conv2d_transpose_4[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# instance_normalization_12 (Inst (None, 8, 8, 256)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 8, 8, 256)    0           instance_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 16, 16, 64)   147520      activation_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 128)  0           conv2d_transpose_5[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# instance_normalization_13 (Inst (None, 16, 16, 128)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 128)  0           instance_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 32, 32, 32)   36896       activation_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 64)   0           conv2d_transpose_6[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 32, 32, 1)    577         concatenate_5[0][0]
# ==================================================================================================
# Total params: 868,449
# Trainable params: 868,449
# Non-trainable params: 0
# __________________________________________________________________________________________________
